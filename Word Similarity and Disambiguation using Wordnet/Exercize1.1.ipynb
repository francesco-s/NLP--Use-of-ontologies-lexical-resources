# %% [markdown]
# ## Exercize 1.1
# ### Word Similarity
# #### Francesco Sannicola

# %% [markdown]
# Import wordnet interface from nltk

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# Read the file which contains couples of word with a human made similarity score

# %%
import csv

def read_csv():
    all_col = []
    with open('./Input/WordSim353.csv', 'r', encoding='utf-8-sig') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=';')
        for col in csv_reader:
            all_col.append(col)
    return all_col

# %% [markdown]
# Split the input file readed into:
# - base: first word
# - target: second word
# - gold: similitary score

# %%
input_file_similarity = read_csv()
input_file_similarity.pop(0)

base = []
target = []
gold = []

for row in input_file_similarity:
    field = row[0].split(',')
    base.append(field[0])
    target.append(field[1])
    gold.append(float(field[2]))

# %% [markdown]
# Method that calculates the lowest common subsumer. Useful for all similarity algoritms.

# %%
def lowest_common_subsumer(syn1, syn2):
    """
    :param syn1: first word's synset
    :param syn2: second word's synset
    :return: common lowest ancestor's synset
    """
    if syn1 == syn2:
        return syn1
    
    commons = []
    
    for s1 in syn1.hypernym_paths():
        for s2 in syn2.hypernym_paths():
            # couples of elements in the same position
            union = list(zip(s1, s2))
            common = None
            
            # find a tuple with equal components
            for i in range(len(union)):
                if union[i][0] != union[i][1]:
                    break
                common = (union[i][0], i)
            if common is not None and common not in commons:
                commons.append(common)

    if len(commons) == 0:
        return None
    
    # return and find the lowest ancestor by reversing commons and take the first one
    commons.sort(key=lambda x: x[1], reverse=True)
    return commons[0][0]

# %% [markdown]
# Get distance between 2 synset.

# %%
def get_distance(syn1, syn2):
    '''
    :param syn1: 1st synset
    :param syn2: 2nd synset
    :return: distance between the given synsets
    '''

    # find the lowest common subsumer betweeen two synsets
    lcs = lowest_common_subsumer(syn1, syn2)
    
    if lcs is None:
        return None
    
    # obtain hypernym paths for both 
    hyper_synset1 = syn1.hypernym_paths()
    hyper_synset2 = syn2.hypernym_paths()

    if syn1 == syn2:
        return 0
    
    # convert a list into a set (for remove method)
    lists_lcs_hyper = lcs.hypernym_paths()
    set_lcs_hyper = set()
    for el in lists_lcs_hyper:
        for i in el:
            set_lcs_hyper.add(i)
            
    # nodes from LCS to root. Delete the LCS
    set_lcs_hyper.remove(lcs)

    # path from both synsets to LCS. Map is defined as map(function, iterable, ...), 
    # function perform some action to each element of an iterable
    hyper_synset1 = list(map(lambda x: [y for y in x if y not in set_lcs_hyper], hyper_synset1))
    hyper_synset2 = list(map(lambda x: [y for y in x if y not in set_lcs_hyper], hyper_synset2))
    
    # mantain only paths with LCS. Filter do that (filter(function, iterable)) 
    hyper_synset1 = list(filter(lambda x: lcs in x, hyper_synset1))
    hyper_synset2 = list(filter(lambda x: lcs in x, hyper_synset2))
    
    # take the min path from both synsets LCS
    distance = min(list(map(lambda x: len(x), hyper_synset1))) + min(list(map(lambda x: len(x), hyper_synset2))) - 2

    return distance

# %% [markdown]
# Obtain the depth of a synset synset. I.e. it mesures the distance between the given synset and the WordNet's root. Result path contains LCS of 2 synset. Method useful for Wu and Palmer metric.

# %%
def get_depth_lcs(syn, lcs):
    '''
    :param syn: synset to reach from the root
    :param lcs: first common sense
    :return: minimum path which contains LCS
    '''
    paths = syn.hypernym_paths()
    paths = list(filter(lambda x: lcs in x, paths))
    return min(len(path) for path in paths)

# %% [markdown]
# First similarity algoritm:
# ### Wu & Palmer
# $$
#   sim(s_1,s_2) = \frac{2 * depth(LCS)}{depth(s_1) + depth(s_2)}
# $$
#  The similarity is based on WordNet structure.
#  \
#  LCS is the lowest common subsumer between two synset and depth(x) is the distance from root to x.
#  \
#  The result value is normalized to match the gold field.

# %%
def wup_sim(syn1, syn2):

    lcs = lowest_common_subsumer(syn1, syn2)
    if lcs is None:
        return 0
    sim = 2 * (get_depth_lcs(lcs, lcs) / (get_depth_lcs(syn1, lcs) + get_depth_lcs(syn2, lcs)))

    return sim * 10

# %% [markdown]
# Calculate the maximum depth of the taxonomy

# %%
max_depth = max(max(len(hyp_path) for hyp_path in ss.hypernym_paths()) for ss in wn.all_synsets())

# %% [markdown]
# ### Leakcock-Chodorow:
# $$
#   sim(s_1,s_2) = -log \frac{len (s_1, s_2)}{2 * depthMax}
# $$
#
# When s1 and s2 have the same sense, len(s1 ,s2)=0.
# \
# In practice, we add 1 to both len(s1 ,s2) and 2*depthMax to avoid log(0). The result is in [0,log(2 * depthMax +1)]

# %%
import math

def leakcock_chodorow_sim(syn1, syn2):

    len = get_distance(syn1, syn2)
    
    if len is None:
        return 0

    if len == 0:
        sim = math.log10((len + 1) / (2 * max_depth + 1))
    else:
        sim = math.log10(len / (2 * max_depth))

    sim = sim * (-1)
    return (sim / (math.log10(2 * max_depth + 1))) * 10

# %% [markdown]
# Implementation of the last similarity method:
# ### Shortest path.
# $$
#   sim(s_1,s_2) = 2 * depthMax - len(s_1, s_2)
# $$
# We have 3 options:
# - if len(s1 ,s2) is 0, sim path (s1 ,s2) gets the maximum value of 2* depthMax.
# - if len(s1 ,s2) is 2* depthMax, sim path (s1 ,s2) gets the minimum value of 0.
# - thus, the values of sim path (s1 ,s2) are between 0 and 2* depthMax.
#
#
# The result is normalized from [0, 2*max_depth] to [0,10]

# %%
def shortest_path_sim(syn1, syn2):
    len = get_distance(syn1, syn2)
    if len is None:
        return 0

    if len == 0:
        sim = 2 * max_depth

    if len == 2 * max_depth:
        sim = 0

    sim = 2 * max_depth - len
    return (sim / 40) * 10

# %% [markdown]
# Call all the methods implemented previously.
#
# For a pair of polysemic words we consider the maximum probability for each sense of each word:
# $$
#   sim(w_1,w_2)=\max_{c1 \in s(w_1), c2 \in s(w_2)} [sim(c_1, c_2)]
# $$

# %%
wup_val = []
lc_val = []
sp_val = []

for i in range(0, len(gold)):

    max_sim = 0
    wup = 0
    for syn1 in wn.synsets(base[i]):
        for syn2 in wn.synsets(target[i]):
            sim = wup_sim(syn1, syn2)
            if sim > max_sim:
                wup = sim
                max_sim = sim
    wup_val.append(wup)

    max_sim = 0
    lc = 0
    for syn1 in wn.synsets(base[i]):
        for syn2 in wn.synsets(target[i]):
            sim = leakcock_chodorow_sim(syn1, syn2)
            if sim > max_sim:
                lc = sim
                max_sim = sim
    lc_val.append(lc)

    max_sim = 0
    sp = 0
    for syn1 in wn.synsets(base[i]):
        for syn2 in wn.synsets(target[i]):
            sim = shortest_path_sim(syn1, syn2)
            if sim > max_sim:
                sp = sim
                max_sim = sim
    sp_val.append(sp)

# %% [markdown]
# Print a table with all similarity.

# %%
from prettytable import PrettyTable

table_res = PrettyTable(["Base", "Target", "Wu & Palmer", "Leakcock & Chodorow", "Shortest-Path", "Gold"])

for i in range(0, len(gold)):
    # print(base[i], target[i], round(wup_val[i], 2), round(lc_val[i], 2), round(sp_val[i], 2), round(gold[i], 2))
    table_res.add_row(
        [base[i], target[i], round(wup_val[i], 2), round(lc_val[i], 2), round(sp_val[i], 2), round(gold[i], 2)])

print(table_res)
# Out:
# +---------------+----------------+-------------+---------------------+---------------+------+
# |      Base     |     Target     | Wu & Palmer | Leakcock & Chodorow | Shortest-Path | Gold |
# +---------------+----------------+-------------+---------------------+---------------+------+
# |      love     |      sex       |     9.23    |         9.93        |      9.75     | 6.77 |
# |     tiger     |      cat       |     9.66    |         9.93        |      9.75     | 7.35 |
# |     tiger     |     tiger      |     10.0    |         10.0        |      10.0     | 10.0 |
# |      book     |     paper      |     8.75    |         8.07        |      9.5      | 7.46 |
# |    computer   |    keyboard    |     8.24    |         6.98        |      9.25     | 7.62 |
# |    computer   |    internet    |     6.32    |         4.69        |      8.25     | 7.58 |
# |     plane     |      car       |     7.27    |         5.11        |      8.5      | 5.77 |
# |     train     |      car       |     7.37    |         5.6         |      8.75     | 6.31 |
# |   telephone   | communication  |     1.67    |         3.73        |      7.5      | 7.5  |
# |   television  |     radio      |     9.09    |         8.07        |      9.5      | 6.77 |
# |     media     |     radio      |     8.24    |         6.98        |      9.25     | 7.42 |
# |      drug     |     abuse      |     1.82    |         4.02        |      7.75     | 6.85 |
# |     bread     |     butter     |     7.5     |         8.07        |      9.5      | 6.19 |
# |    cucumber   |     potato     |     8.24    |         6.98        |      9.25     | 5.92 |
# |     doctor    |     nurse      |     8.24    |         8.07        |      9.5      | 7.0  |
# |   professor   |     doctor     |     6.67    |         5.11        |      8.5      | 6.62 |
# |    student    |   professor    |     5.33    |         4.69        |      8.25     | 6.81 |
# |     smart     |    student     |     1.33    |         3.03        |      6.75     | 4.62 |
# |     smart     |     stupid     |     1.33    |         3.03        |      6.75     | 5.81 |
# |    company    |     stock      |     6.15    |         5.6         |      8.75     | 7.08 |
# |     stock     |     market     |     5.56    |         5.11        |      8.5      | 8.08 |
# |     stock     |     phone      |     7.0     |         5.11        |      8.5      | 1.62 |
# |     stock     |       CD       |     7.37    |         5.6         |      8.75     | 1.31 |
# |     stock     |     jaguar     |     8.15    |         5.6         |      8.75     | 0.92 |
# |     stock     |      egg       |     6.25    |         5.11        |      8.5      | 1.81 |
# |   fertility   |      egg       |     1.54    |         3.48        |      7.25     | 6.69 |
# |     stock     |      live      |     2.86    |         5.6         |      8.75     | 3.73 |
# |     stock     |      life      |     6.15    |         5.6         |      8.75     | 0.92 |
# |      book     |    library     |     8.0     |         8.07        |      9.5      | 7.46 |
# |      bank     |     money      |     5.71    |         5.11        |      8.5      | 8.12 |
# |      wood     |     forest     |     10.0    |         10.0        |      10.0     | 7.73 |
# |     money     |      cash      |     8.75    |         8.07        |      9.5      | 9.15 |
# |   professor   |    cucumber    |     5.0     |         3.24        |      7.0      | 0.31 |
# |      king     |    cabbage     |     5.71    |         4.02        |      7.75     | 0.23 |
# |      king     |     queen      |     10.0    |         10.0        |      10.0     | 8.58 |
# |      king     |      rook      |     9.09    |         8.07        |      9.5      | 5.92 |
# |     bishop    |     rabbi      |     7.5     |         6.2         |      9.0      | 6.69 |
# |   Jerusalem   |     Israel     |     7.0     |         5.11        |      8.5      | 8.46 |
# |   Jerusalem   |  Palestinian   |     2.73    |         2.47        |      6.0      | 7.65 |
# |      holy     |      sex       |     3.08    |         4.02        |      7.75     | 1.62 |
# |      fuck     |      sex       |     8.57    |         8.07        |      9.5      | 9.44 |
# |    Maradona   |    football    |      0      |          0          |       0       | 8.62 |
# |    football   |     soccer     |     9.52    |         9.93        |      9.75     | 9.03 |
# |    football   |   basketball   |     9.0     |         8.07        |      9.5      | 6.81 |
# |    football   |     tennis     |     7.62    |         5.6         |      8.75     | 6.63 |
# |     tennis    |     racket     |     6.0     |         4.33        |      8.0      | 7.56 |
# |     Arafat    |     peace      |     1.43    |         3.24        |      7.0      | 6.73 |
# |     Arafat    |     terror     |     6.15    |         5.6         |      8.75     | 7.65 |
# |     Arafat    |    Jackson     |     8.0     |         6.98        |      9.25     | 2.5  |
# |      law      |     lawyer     |     1.67    |         3.73        |      7.5      | 8.38 |
# |     movie     |      star      |     5.33    |         4.69        |      8.25     | 7.38 |
# |     movie     |    popcorn     |     3.64    |         3.03        |      6.75     | 6.19 |
# |     movie     |     critic     |     4.44    |         3.73        |      7.5      | 6.73 |
# |     movie     |    theater     |     6.25    |         5.11        |      8.5      | 7.92 |
# |    physics    |     proton     |     2.22    |         2.83        |      6.5      | 8.12 |
# |    physics    |   chemistry    |     9.0     |         8.07        |      9.5      | 7.35 |
# |     space     |   chemistry    |     4.44    |         5.6         |      8.75     | 4.88 |
# |    alcohol    |   chemistry    |     6.67    |         6.2         |      9.0      | 5.54 |
# |     vodka     |      gin       |     8.89    |         8.07        |      9.5      | 8.46 |
# |     vodka     |     brandy     |     8.89    |         8.07        |      9.5      | 8.13 |
# |     drink     |      car       |     2.86    |         3.73        |      7.5      | 3.04 |
# |     drink     |      ear       |     4.62    |         4.69        |      8.25     | 1.31 |
# |     drink     |     mouth      |     5.0     |         5.11        |      8.5      | 5.96 |
# |     drink     |      eat       |     5.0     |         8.07        |      9.5      | 6.87 |
# |      baby     |     mother     |     7.5     |         6.2         |      9.0      | 7.85 |
# |     drink     |     mother     |     6.15    |         5.6         |      8.75     | 2.65 |
# |      car      |   automobile   |     10.0    |         10.0        |      10.0     | 8.94 |
# |      gem      |     jewel      |     10.0    |         10.0        |      10.0     | 8.96 |
# |    journey    |     voyage     |     9.52    |         9.93        |      9.75     | 9.29 |
# |      boy      |      lad       |     9.23    |         9.93        |      9.75     | 8.83 |
# |     coast     |     shore      |     9.09    |         9.93        |      9.75     | 9.1  |
# |     asylum    |    madhouse    |     9.52    |         9.93        |      9.75     | 8.87 |
# |    magician   |     wizard     |     10.0    |         10.0        |      10.0     | 9.02 |
# |     midday    |      noon      |     10.0    |         10.0        |      10.0     | 9.29 |
# |    furnace    |     stove      |     5.26    |         4.02        |      7.75     | 8.79 |
# |      food     |     fruit      |     4.0     |         4.02        |      7.75     | 7.52 |
# |      bird     |      cock      |     9.52    |         9.93        |      9.75     | 7.1  |
# |      bird     |     crane      |     8.7     |         6.98        |      9.25     | 7.38 |
# |      tool     |   implement    |     9.33    |         9.93        |      9.75     | 6.46 |
# |    brother    |      monk      |     9.33    |         9.93        |      9.75     | 6.27 |
# |     crane     |   implement    |     7.5     |         6.2         |      9.0      | 2.69 |
# |      lad      |    brother     |     6.67    |         6.2         |      9.0      | 4.46 |
# |    journey    |      car       |     1.05    |         2.3         |      5.75     | 5.85 |
# |      monk     |     oracle     |     5.33    |         4.69        |      8.25     | 5.0  |
# |    cemetery   |    woodland    |     4.29    |         4.33        |      8.0      | 2.08 |
# |      food     |    rooster     |     2.11    |         2.64        |      6.25     | 4.42 |
# |     coast     |      hill      |     6.67    |         6.2         |      9.0      | 4.38 |
# |     forest    |   graveyard    |     4.29    |         4.33        |      8.0      | 1.85 |
# |     shore     |    woodland    |     6.0     |         6.2         |      9.0      | 3.08 |
# |      monk     |     slave      |     6.67    |         6.2         |      9.0      | 0.92 |
# |     coast     |     forest     |     5.45    |         5.6         |      8.75     | 3.15 |
# |      lad      |     wizard     |     6.67    |         6.2         |      9.0      | 0.92 |
# |     chord     |     smile      |     3.75    |         3.73        |      7.5      | 0.54 |
# |     glass     |    magician    |     4.71    |         4.69        |      8.25     | 2.08 |
# |      noon     |     string     |     2.67    |         3.48        |      7.25     | 0.54 |
# |    rooster    |     voyage     |     0.8     |         1.49        |      4.25     | 0.62 |
# |     money     |     dollar     |     7.78    |         6.2         |      9.0      | 8.42 |
# |     money     |      cash      |     8.75    |         8.07        |      9.5      | 9.08 |
# |     money     |    currency    |     9.33    |         9.93        |      9.75     | 9.04 |
# |     money     |     wealth     |     9.23    |         9.93        |      9.75     | 8.27 |
# |     money     |    property    |     8.33    |         8.07        |      9.5      | 7.57 |
# |     money     |   possession   |     7.27    |         6.98        |      9.25     | 7.29 |
# |     money     |      bank      |     5.71    |         5.11        |      8.5      | 8.5  |
# |     money     |    deposit     |     8.75    |         8.07        |      9.5      | 7.73 |
# |     money     |   withdrawal   |     2.86    |         3.73        |      7.5      | 6.88 |
# |     money     |   laundering   |     2.5     |         3.24        |      7.0      | 5.65 |
# |     money     |   operation    |     3.33    |         4.33        |      8.0      | 3.31 |
# |     tiger     |     jaguar     |     9.33    |         8.07        |      9.5      | 8.0  |
# |     tiger     |     feline     |     9.29    |         8.07        |      9.5      | 8.0  |
# |     tiger     |   carnivore    |     8.89    |         6.98        |      9.25     | 7.08 |
# |     tiger     |     mammal     |     8.0     |         5.6         |      8.75     | 6.85 |
# |     tiger     |     animal     |     8.0     |         6.98        |      9.25     | 7.0  |
# |     tiger     |    organism    |     8.57    |         8.07        |      9.5      | 4.77 |
# |     tiger     |     fauna      |     8.0     |         6.98        |      9.25     | 5.62 |
# |     tiger     |      zoo       |     5.33    |         4.69        |      8.25     | 5.87 |
# |   psychology  |   psychiatry   |     7.27    |         5.11        |      8.5      | 8.08 |
# |   psychology  |    anxiety     |     2.5     |         3.24        |      7.0      | 7.0  |
# |   psychology  |      fear      |     2.5     |         3.24        |      7.0      | 6.85 |
# |   psychology  |   depression   |     3.53    |         3.48        |      7.25     | 7.42 |
# |   psychology  |     clinic     |     2.35    |         3.03        |      6.75     | 6.58 |
# |   psychology  |     doctor     |     3.33    |         3.24        |      7.0      | 6.42 |
# |   psychology  |     Freud      |     0.95    |         2.0         |      5.25     | 8.21 |
# |   psychology  |      mind      |     5.88    |         5.11        |      8.5      | 7.69 |
# |   psychology  |     health     |     2.67    |         3.48        |      7.25     | 7.23 |
# |   psychology  |    science     |     9.41    |         9.93        |      9.75     | 6.71 |
# |   psychology  |   discipline   |     8.75    |         8.07        |      9.5      | 5.58 |
# |   psychology  |   cognition    |     6.15    |         5.6         |      8.75     | 7.48 |
# |     planet    |      star      |     8.57    |         8.07        |      9.5      | 8.45 |
# |     planet    | constellation  |     7.69    |         6.98        |      9.25     | 8.06 |
# |     planet    |      moon      |     8.0     |         6.98        |      9.25     | 8.08 |
# |     planet    |      sun       |     8.0     |         6.98        |      9.25     | 8.02 |
# |     planet    |     galaxy     |     6.32    |         4.69        |      8.25     | 8.11 |
# |     planet    |     space      |     5.33    |         5.11        |      8.5      | 7.92 |
# |     planet    |   astronomer   |     6.15    |         5.6         |      8.75     | 7.94 |
# |   precedent   |    example     |     9.23    |         9.93        |      9.75     | 5.85 |
# |   precedent   |  information   |     8.33    |         8.07        |      9.5      | 3.85 |
# |   precedent   |   cognition    |     7.27    |         6.98        |      9.25     | 2.81 |
# |   precedent   |      law       |     9.09    |         9.93        |      9.75     | 6.65 |
# |   precedent   |   collection   |     8.0     |         8.07        |      9.5      | 2.5  |
# |   precedent   |     group      |     6.67    |         6.98        |      9.25     | 1.77 |
# |   precedent   |   antecedent   |     6.15    |         5.6         |      8.75     | 6.04 |
# |      cup      |     coffee     |     7.37    |         5.6         |      8.75     | 6.58 |
# |      cup      |   tableware    |     8.89    |         8.07        |      9.5      | 6.85 |
# |      cup      |    article     |     7.5     |         6.2         |      9.0      | 2.4  |
# |      cup      |    artifact    |     7.69    |         6.98        |      9.25     | 2.92 |
# |      cup      |     object     |     5.45    |         5.6         |      8.75     | 3.69 |
# |      cup      |     entity     |     2.86    |         5.6         |      8.75     | 2.15 |
# |      cup      |     drink      |     7.5     |         6.2         |      9.0      | 7.25 |
# |      cup      |      food      |     6.67    |         5.6         |      8.75     | 5.0  |
# |      cup      |   substance    |     5.71    |         5.11        |      8.5      | 1.92 |
# |      cup      |     liquid     |     7.06    |         5.6         |      8.75     | 5.9  |
# |     jaguar    |      cat       |     9.66    |         9.93        |      9.75     | 7.42 |
# |     jaguar    |      car       |     3.33    |         2.47        |      6.0      | 7.27 |
# |     energy    |   secretary    |     2.86    |         3.73        |      7.5      | 1.81 |
# |   secretary   |     senate     |     1.33    |         3.03        |      6.75     | 5.06 |
# |     energy    |   laboratory   |     3.08    |         4.02        |      7.75     | 5.09 |
# |    computer   |   laboratory   |     4.0     |         4.02        |      7.75     | 6.78 |
# |     weapon    |     secret     |     2.86    |         3.73        |      7.5      | 6.06 |
# |      FBI      |  fingerprint   |     2.5     |         3.24        |      7.0      | 6.94 |
# |      FBI      | investigation  |     2.22    |         2.83        |      6.5      | 8.31 |
# | investigation |     effort     |     8.24    |         6.98        |      9.25     | 4.59 |
# |      Mars     |     water      |     5.0     |         6.2         |      9.0      | 2.94 |
# |      Mars     |   scientist    |     4.71    |         4.02        |      7.75     | 5.63 |
# |      news     |     report     |     9.23    |         9.93        |      9.75     | 8.16 |
# |     canyon    |   landscape    |     3.53    |         3.48        |      7.25     | 7.53 |
# |     image     |    surface     |     7.14    |         6.2         |      9.0      | 4.56 |
# |   discovery   |     space      |     4.0     |         5.11        |      8.5      | 6.34 |
# |     water     |    seepage     |     2.5     |         3.48        |      7.25     | 6.56 |
# |      sign     |     recess     |     7.5     |         8.07        |      9.5      | 2.38 |
# |   Wednesday   |      news      |     2.67    |         3.48        |      7.25     | 2.22 |
# |      mile     |   kilometer    |     8.0     |         6.98        |      9.25     | 8.66 |
# |    computer   |      news      |     1.67    |         3.73        |      7.5      | 4.47 |
# |   territory   |    surface     |     6.15    |         5.6         |      8.75     | 5.34 |
# |   atmosphere  |   landscape    |     5.0     |         4.33        |      8.0      | 3.69 |
# |   president   |     medal      |     2.35    |         3.24        |      7.0      | 3.0  |
# |      war      |     troops     |     3.08    |         4.02        |      7.75     | 8.13 |
# |     record    |     number     |     9.09    |         9.93        |      9.75     | 6.31 |
# |      skin     |      eye       |     6.67    |         5.6         |      8.75     | 6.22 |
# |    Japanese   |    American    |     7.69    |         6.98        |      9.25     | 6.5  |
# |    theater    |    history     |     5.0     |         5.11        |      8.5      | 3.91 |
# |   volunteer   |     motto      |     1.54    |         3.48        |      7.25     | 2.56 |
# |   prejudice   |  recognition   |     6.67    |         5.6         |      8.75     | 3.0  |
# |   decoration  |     valor      |     2.67    |         3.48        |      7.25     | 5.63 |
# |    century    |      year      |     8.33    |         8.07        |      9.5      | 7.59 |
# |    century    |     nation     |     3.64    |         4.69        |      8.25     | 3.16 |
# |     delay     |     racism     |     6.25    |         5.11        |      8.5      | 1.19 |
# |     delay     |      news      |     5.33    |         4.69        |      8.25     | 3.31 |
# |    minister   |     party      |     6.15    |         5.6         |      8.75     | 6.63 |
# |     peace     |      plan      |     3.08    |         4.02        |      7.75     | 4.75 |
# |    minority   |     peace      |     6.15    |         5.6         |      8.75     | 3.69 |
# |    attempt    |     peace      |     3.08    |         4.02        |      7.75     | 4.25 |
# |   government  |     crisis     |     5.71    |         5.11        |      8.5      | 6.56 |
# |   deployment  |   departure    |     7.14    |         6.2         |      9.0      | 4.25 |
# |   deployment  |   withdrawal   |     7.78    |         6.2         |      9.0      | 5.88 |
# |     energy    |     crisis     |     6.25    |         5.11        |      8.5      | 5.94 |
# |  announcement |      news      |     6.67    |         6.2         |      9.0      | 7.56 |
# |  announcement |     effort     |     3.08    |         4.02        |      7.75     | 2.75 |
# |     stroke    |    hospital    |     4.0     |         3.73        |      7.5      | 7.03 |
# |   disability  |     death      |     5.33    |         4.69        |      8.25     | 5.47 |
# |     victim    |   emergency    |     4.44    |         4.02        |      7.75     | 6.47 |
# |   treatment   |    recovery    |     7.69    |         6.98        |      9.25     | 7.91 |
# |    journal    |  association   |     4.0     |         5.11        |      8.5      | 4.97 |
# |     doctor    |   personnel    |     2.67    |         3.48        |      7.25     | 5.0  |
# |     doctor    |   liability    |     2.67    |         3.48        |      7.25     | 5.19 |
# |   liability   |   insurance    |     6.25    |         5.11        |      8.5      | 7.03 |
# |     school    |     center     |     8.75    |         8.07        |      9.5      | 3.44 |
# |     reason    |  hypertension  |     5.56    |         4.33        |      8.0      | 2.31 |
# |     reason    |   criterion    |     5.33    |         4.69        |      8.25     | 5.91 |
# |    hundred    |    percent     |     2.5     |         3.24        |      7.0      | 7.38 |
# |    Harvard    |      Yale      |     8.89    |         8.07        |      9.5      | 8.13 |
# |    hospital   | infrastructure |     2.67    |         3.48        |      7.25     | 4.63 |
# |     death     |      row       |     5.0     |         4.69        |      8.25     | 5.25 |
# |     death     |     inmate     |     2.86    |         3.73        |      7.5      | 5.03 |
# |     lawyer    |    evidence    |     1.67    |         3.73        |      7.5      | 6.69 |
# |      life     |     death      |     8.57    |         8.07        |      9.5      | 7.88 |
# |      life     |      term      |     8.57    |         8.07        |      9.5      | 4.5  |
# |      word     |   similarity   |     4.55    |         4.33        |      8.0      | 4.75 |
# |     board     | recommendation |     2.67    |         3.48        |      7.25     | 4.47 |
# |    governor   |   interview    |     1.33    |         3.03        |      6.75     | 3.25 |
# |      OPEC     |    country     |     6.25    |         5.11        |      8.5      | 5.63 |
# |     peace     |   atmosphere   |     7.14    |         6.2         |      9.0      | 3.69 |
# |     peace     |   insurance    |     8.24    |         6.98        |      9.25     | 2.94 |
# |   territory   |   kilometer    |     2.5     |         3.24        |      7.0      | 5.28 |
# |     travel    |    activity    |     6.67    |         5.6         |      8.75     | 5.0  |
# |  competition  |     price      |     5.0     |         4.69        |      8.25     | 6.44 |
# |    consumer   |   confidence   |     1.54    |         3.48        |      7.25     | 4.13 |
# |    consumer   |     energy     |     3.08    |         4.02        |      7.75     | 4.75 |
# |    problem    |    airport     |     1.33    |         3.03        |      6.75     | 2.38 |
# |      car      |     flight     |     5.88    |         4.69        |      8.25     | 4.94 |
# |     credit    |      card      |     6.15    |         5.6         |      8.75     | 8.06 |
# |     credit    |  information   |     7.27    |         6.98        |      9.25     | 5.31 |
# |     hotel     |  reservation   |     3.75    |         3.73        |      7.5      | 8.03 |
# |    grocery    |     money      |     1.33    |         3.03        |      6.75     | 5.94 |
# |  registration |  arrangement   |     6.67    |         6.2         |      9.0      | 6.0  |
# |  arrangement  | accommodation  |     6.67    |         5.11        |      8.5      | 5.41 |
# |     month     |     hotel      |     1.54    |         3.48        |      7.25     | 1.81 |
# |      type     |      kind      |     9.47    |         9.93        |      9.75     | 8.97 |
# |    arrival    |     hotel      |     4.71    |         4.02        |      7.75     | 6.0  |
# |      bed      |     closet     |     8.42    |         6.98        |      9.25     | 6.72 |
# |     closet    |    clothes     |     5.88    |         4.69        |      8.25     | 8.0  |
# |   situation   |   conclusion   |     6.25    |         5.11        |      8.5      | 4.81 |
# |   situation   |   isolation    |     7.27    |         6.98        |      9.25     | 3.88 |
# |  impartiality |    interest    |     4.0     |         4.33        |      8.0      | 5.16 |
# |   direction   |  combination   |     6.67    |         5.11        |      8.5      | 2.25 |
# |     street    |     place      |     6.15    |         5.6         |      8.75     | 6.44 |
# |     street    |     avenue     |     9.47    |         9.93        |      9.75     | 8.88 |
# |     street    |     block      |     6.67    |         5.6         |      8.75     | 6.88 |
# |     street    |    children    |     4.71    |         4.02        |      7.75     | 4.94 |
# |    listing    |   proximity    |     3.16    |         3.24        |      7.0      | 2.56 |
# |    listing    |    category    |     3.75    |         4.33        |      8.0      | 6.38 |
# |      cell     |     phone      |     9.0     |         8.07        |      9.5      | 7.81 |
# |   production  |      hike      |     5.88    |         4.69        |      8.25     | 1.75 |
# |   benchmark   |     index      |     7.69    |         6.98        |      9.25     | 4.25 |
# |     media     |    trading     |     6.25    |         5.11        |      8.5      | 3.88 |
# |     media     |      gain      |     5.0     |         5.11        |      8.5      | 2.88 |
# |    dividend   |    payment     |     8.89    |         8.07        |      9.5      | 7.63 |
# |    dividend   |  calculation   |     2.86    |         3.73        |      7.5      | 6.48 |
# |  calculation  |  computation   |     10.0    |         10.0        |      10.0     | 8.44 |
# |    currency   |     market     |     3.08    |         4.02        |      7.75     | 7.5  |
# |      OPEC     |      oil       |     2.22    |         2.83        |      6.5      | 8.59 |
# |      oil      |     stock      |     5.71    |         4.33        |      8.0      | 6.34 |
# |  announcement |   production   |     5.0     |         5.11        |      8.5      | 3.38 |
# |  announcement |    warning     |     6.15    |         5.6         |      8.75     | 6.0  |
# |     profit    |    warning     |     2.86    |         3.73        |      7.5      | 3.88 |
# |     profit    |      loss      |     7.06    |         5.6         |      8.75     | 7.63 |
# |     dollar    |      yen       |     8.0     |         6.98        |      9.25     | 7.78 |
# |     dollar    |      buck      |     10.0    |         10.0        |      10.0     | 9.22 |
# |     dollar    |     profit     |     3.08    |         4.02        |      7.75     | 7.38 |
# |     dollar    |      loss      |     3.33    |         4.33        |      8.0      | 6.09 |
# |    computer   |    software    |     1.43    |         3.24        |      7.0      | 8.5  |
# |    network    |    hardware    |     8.0     |         6.98        |      9.25     | 8.31 |
# |     phone     |   equipment    |     8.75    |         8.07        |      9.5      | 7.13 |
# |   equipment   |     maker      |     5.0     |         4.33        |      8.0      | 5.91 |
# |     luxury    |      car       |     1.25    |         2.83        |      6.5      | 6.47 |
# |      five     |     month      |     4.62    |         4.69        |      8.25     | 3.38 |
# |     report    |      gain      |     3.64    |         4.69        |      8.25     | 3.63 |
# |    investor   |    earning     |      0      |          0          |       0       | 7.13 |
# |     liquid    |     water      |     9.23    |         9.93        |      9.75     | 7.89 |
# |    baseball   |     season     |     2.22    |         2.83        |      6.5      | 5.97 |
# |      game     |    victory     |     5.71    |         5.11        |      8.5      | 7.03 |
# |      game     |      team      |     3.08    |         4.02        |      7.75     | 7.69 |
# |    marathon   |     sprint     |     5.0     |         3.73        |      7.5      | 7.47 |
# |      game     |     series     |     8.57    |         8.07        |      9.5      | 6.19 |
# |      game     |     defeat     |     5.71    |         5.11        |      8.5      | 6.97 |
# |     seven     |     series     |     3.75    |         4.33        |      8.0      | 3.56 |
# |    seafood    |      sea       |     3.64    |         4.69        |      8.25     | 7.47 |
# |    seafood    |      food      |     9.09    |         9.93        |      9.75     | 8.34 |
# |    seafood    |    lobster     |     8.57    |         8.07        |      9.5      | 8.7  |
# |    lobster    |      food      |     7.69    |         6.98        |      9.25     | 7.81 |
# |    lobster    |      wine      |     3.75    |         3.73        |      7.5      | 5.7  |
# |      food     |  preparation   |     5.71    |         5.11        |      8.5      | 6.22 |
# |     video     |    archive     |     5.56    |         4.33        |      8.0      | 6.34 |
# |     start     |      year      |     5.45    |         5.6         |      8.75     | 4.06 |
# |     start     |     match      |     5.71    |         6.98        |      9.25     | 4.47 |
# |      game     |     round      |     8.89    |         8.07        |      9.5      | 5.97 |
# |     boxing    |     round      |     7.27    |         5.11        |      8.5      | 7.61 |
# |  championship |   tournament   |     8.57    |         8.07        |      9.5      | 8.36 |
# |    fighting   |   defeating    |     2.86    |         3.73        |      7.5      | 7.41 |
# |      line     |   insurance    |     7.14    |         6.2         |      9.0      | 2.69 |
# |      day      |     summer     |     7.69    |         6.98        |      9.25     | 3.94 |
# |     summer    |    drought     |     7.69    |         6.98        |      9.25     | 7.16 |
# |     summer    |     nature     |     3.33    |         4.33        |      8.0      | 5.63 |
# |      day      |      dawn      |     8.33    |         8.07        |      9.5      | 7.53 |
# |     nature    |  environment   |     5.45    |         5.6         |      8.75     | 8.31 |
# |  environment  |    ecology     |     9.23    |         9.93        |      9.75     | 8.81 |
# |     nature    |      man       |     6.67    |         6.98        |      9.25     | 6.25 |
# |      man      |     woman      |     8.33    |         8.07        |      9.5      | 8.3  |
# |      man      |    governor    |     6.67    |         6.2         |      9.0      | 5.25 |
# |     murder    |  manslaughter  |     9.17    |         8.07        |      9.5      | 8.53 |
# |      soap     |     opera      |     2.35    |         3.03        |      6.75     | 7.94 |
# |     opera     |  performance   |     3.08    |         4.02        |      7.75     | 6.88 |
# |      life     |     lesson     |     4.29    |         4.69        |      8.25     | 5.94 |
# |     focus     |      life      |     5.33    |         5.11        |      8.5      | 4.06 |
# |   production  |      crew      |     3.64    |         4.69        |      8.25     | 6.25 |
# |   television  |      film      |     7.78    |         6.2         |      9.0      | 7.72 |
# |     lover     |    quarrel     |     4.0     |         3.24        |      7.0      | 6.19 |
# |     viewer    |     serial     |     5.0     |         3.73        |      7.5      | 2.97 |
# |  possibility  |      girl      |     1.67    |         3.73        |      7.5      | 1.94 |
# |   population  |  development   |     7.27    |         5.11        |      8.5      | 3.75 |
# |    morality   |   importance   |     6.67    |         6.2         |      9.0      | 3.31 |
# |    morality   |    marriage    |     5.45    |         5.6         |      8.75     | 3.69 |
# |     Mexico    |     Brazil     |     8.0     |         6.2         |      9.0      | 7.44 |
# |     gender    |    equality    |     4.62    |         4.69        |      8.25     | 6.41 |
# |     change    |    attitude    |     5.45    |         5.6         |      8.75     | 5.44 |
# |     family    |    planning    |     3.08    |         4.02        |      7.75     | 6.25 |
# |     opera     |    industry    |     2.86    |         3.73        |      7.5      | 2.63 |
# |     sugar     |    approach    |     2.86    |         3.73        |      7.5      | 0.88 |
# |    practice   |  institution   |     8.33    |         8.07        |      9.5      | 3.19 |
# |    ministry   |    culture     |     5.33    |         4.69        |      8.25     | 4.69 |
# |    problem    |   challenge    |     6.15    |         5.6         |      8.75     | 6.75 |
# |      size     |   prominence   |     6.15    |         5.6         |      8.75     | 5.31 |
# |    country    |    citizen     |     4.0     |         4.02        |      7.75     | 7.31 |
# |     planet    |     people     |     2.0     |         4.33        |      8.0      | 5.75 |
# |  development  |     issue      |     7.5     |         6.98        |      9.25     | 3.97 |
# |   experience  |     music      |     6.15    |         5.6         |      8.75     | 3.47 |
# |     music     |    project     |     8.0     |         6.98        |      9.25     | 3.63 |
# |     glass     |     metal      |     5.45    |         5.6         |      8.75     | 5.56 |
# |    aluminum   |     metal      |     9.23    |         9.93        |      9.75     | 7.83 |
# |     chance    |  credibility   |     5.0     |         5.6         |      8.75     | 3.88 |
# |    exhibit    |  memorabilia   |     4.29    |         4.33        |      8.0      | 5.31 |
# |    concert    |    virtuoso    |     1.43    |         3.24        |      7.0      | 6.81 |
# |      rock     |      jazz      |     8.57    |         8.07        |      9.5      | 7.59 |
# |     museum    |    theater     |     6.25    |         5.11        |      8.5      | 7.19 |
# |  observation  |  architecture  |     7.06    |         5.6         |      8.75     | 4.38 |
# |     space     |     world      |     5.71    |         6.2         |      9.0      | 6.53 |
# |  preservation |     world      |     5.88    |         5.11        |      8.5      | 6.19 |
# |   admission   |     ticket     |     5.71    |         5.11        |      8.5      | 7.69 |
# |     shower    |  thunderstorm  |     7.0     |         5.11        |      8.5      | 6.31 |
# |     shower    |     flood      |     6.36    |         6.2         |      9.0      | 6.03 |
# |    weather    |    forecast    |     1.33    |         3.03        |      6.75     | 8.34 |
# |    disaster   |      area      |     5.0     |         4.33        |      8.0      | 6.25 |
# |    governor   |     office     |     5.26    |         4.02        |      7.75     | 6.34 |
# |  architecture |    century     |     3.08    |         4.02        |      7.75     | 3.78 |
# +---------------+----------------+-------------+---------------------+---------------+------+

# %% [markdown]
# Import some useful library to compute correlation coeffincents.

# %%
import numpy
from numpy import cov, std
from scipy.stats import rankdata

# %% [markdown]
# Implementation of Spearman's rank correlation coefficent:
# $$
#   r_s= \frac{cov (rg_x, rg_y)}{σ_{rg_{X}} * σ_{rg_{Y}} }
# $$

# %%
def spearman_index(target, predicted):
    '''
    :param target: gold value
    :param predicted: computed value
    :return: value of the spearman's correlation
    '''
    target = numpy.array(target).astype(numpy.float)
    predicted = numpy.array(predicted).astype(numpy.float)
    return cov(rankdata(target), rankdata(predicted))[0][1] / (std(rankdata(target)) * std(rankdata(predicted)))

# %% [markdown]
# Implementation of Pearson's correlation coefficent:
# $$
#   r_s= \frac{cov (X, Y)}{σ_{X} * σ_{Y} }
# $$

# %%
def pearson_index(target, predicted):
    '''
        :param target: gold value
        :param predicted: computed value
        :return: value of the pearson's correlation
    '''
    target = numpy.array(target).astype(numpy.float)
    predicted = numpy.array(predicted).astype(numpy.float)
    return cov(target, predicted)[0][1] / (std(target) * std(predicted))

# %% [markdown]
# Print correlation result of both technique for all similarity metrics.

# %%
table_res_pearson = PrettyTable(["Coefficent", "Value"])

print ("-----------------Pearson coefficent-----------------")
table_res_pearson.add_row(["Wu & Palmer", pearson_index(gold, wup_val)])
table_res_pearson.add_row(["Leakcock & Chodorow", pearson_index(gold, lc_val)])
table_res_pearson.add_row(["Shortest-Path", pearson_index(gold, sp_val)])
print(table_res_pearson)

table_res_spearman = PrettyTable(["Coefficent", "Value"])
print ("-----------------Spearman coefficent-----------------")
table_res_spearman.add_row(["Wu & Palmer", spearman_index(gold, wup_val)])
table_res_spearman.add_row(["Leakcock & Chodorow", spearman_index(gold, lc_val)])
table_res_spearman.add_row(["Shortest-Path", spearman_index(gold, sp_val)])
print(table_res_spearman)
# Out:
# -----------------Pearson coefficent-----------------
# +---------------------+---------------------+
# |      Coefficent     |        Value        |
# +---------------------+---------------------+
# |     Wu & Palmer     |  0.2881726141884054 |
# | Leakcock & Chodorow | 0.31827728260366556 |
# |    Shortest-Path    | 0.16458563735418705 |
# +---------------------+---------------------+
# -----------------Spearman coefficent-----------------
# +---------------------+---------------------+
# |      Coefficent     |        Value        |
# +---------------------+---------------------+
# |     Wu & Palmer     | 0.33724305240662467 |
# | Leakcock & Chodorow | 0.28912011037697033 |
# |    Shortest-Path    | 0.28912011037697033 |
# +---------------------+---------------------+

# %% [markdown]
# ##### The result shows that all three similarity metric does not perform very well. This is predictable considering task difficulty.
#
# ##### However, seems that the Wu & Palmer and the Leakcock & Chodorow have better performance compared to the Shortest-Path metric.
